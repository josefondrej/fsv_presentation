# %% [markdown]
# Recognizing 3 and 4 from images
# ===============================

# %% [markdown]
# ## Load data

# %%
from recognize_numbers import *

# %%
data = load_data()
print(f"Loaded {len(data)} images containing 3 or 4")
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1130 13:15:15.269589 140044969154368 dataset_builder.py:439] Warning: Setting shuffle_files=True because split=TRAIN and shuffle_files=None. This behavior will be deprecated on 2019-08-06, at which point shuffle_files=False will be the default for all splits.
# Loaded 1195 images containing 3 or 4

# %% [markdown]
# ## Plot data

# %%
images = [image for image, label in data[:32]]
plot_data_sample(images)

# %%
image, label = data[0]
plot_image(image)
# Out:
# /home/josef/dev/fsv_presentation/recognize_numbers.py:38: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.axes()

# %% [markdown]
# ## Generate random mask

# %%
random_mask = generate_random_mask()

# %%
plot_image(random_mask)

# %%
correct_prediction_percentage = evaluate_mask(random_mask, data)
print(f"Mask has about {(int)(correct_prediction_percentage * 100):.2f} % of predictions correct.")
# Out:
# Mask has about 57.00 % of predictions correct.

# %% [markdown]
# ## Find good mask

# %%
np.random.seed(647685)

best_mask = None

best_correct_prediction_percentage = 0.

while True: 
    random_mask = generate_random_mask()
    correct_prediction_percentage = evaluate_mask(random_mask, data)
    
    if correct_prediction_percentage > best_correct_prediction_percentage:
        best_correct_prediction_percentage = correct_prediction_percentage
        best_mask = random_mask
        
        print(f"Best mask score so far: {(correct_prediction_percentage * 100) :.2f} %")
    
    if best_correct_prediction_percentage > 0.9: 
        break
# Out:
# Best mask score so far: 54.98 %
# Best mask score so far: 62.09 %
# Best mask score so far: 66.78 %
# Best mask score so far: 70.79 %
# Best mask score so far: 76.32 %
# Best mask score so far: 78.33 %
# Best mask score so far: 82.93 %
# Best mask score so far: 93.31 %

# %%
plot_image(best_mask)

# %%
f"Mask has about {evaluate_mask(best_mask, data)*100 :.2f} % of predictions correct."
# Out:
# 'Mask has about 93.31 % of predictions correct.'

# %% [markdown]
# ## Try to predict using that mask

# %%
predictions = [predict(best_mask, image) for image, label in data[:32]]

# %%
plot_data_sample(images, predictions)
